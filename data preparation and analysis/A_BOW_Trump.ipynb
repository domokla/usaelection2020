# %% [markdown]
# # Trump BOW modell

# %% [markdown]
# libek

# %%
import pandas as pd
import re
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import glob
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords

# %% [markdown]
# Adatok beolvasása, duplikáció szűrés

# %%
#összes TRUMP adat

####################
#összes megadott csv beolvasás
csv = "trump"
nemkell ="#biden"

####################


all_files = glob.glob('data/' + csv + '*.csv')

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
print(df.shape)

#duplikáció kiszűrés tweet azonosítón
df = df.drop_duplicates(subset=['tweetID'])
print(df.shape)

#szavak kiszűrése az elemzésből
df = df[~df.tweetText.str.contains(nemkell, case=False)]
print(df.shape)

#df = pd.read_csv("data/trump20200703.csv")

df['date'] = pd.to_datetime(df.letoltes_datum, format='%Y-%m-%d')
trump=df
print(trump.shape)
# Out:
# (384037, 24)
# (384037, 24)
# (368058, 24)
# (368058, 25)

# %% [markdown]
# Külföldi adatok szűrése

# %%
man = pd.read_csv('location_man.csv', index_col=None, header=0, sep=";", encoding= 'unicode_escape')
df2 = df.set_index('userLocation').join(man.set_index('userLocation')).reset_index()
df2.to_csv('df2.csv',index=False, sep=';', encoding = "utf-8")

df3 = df2[df2['usa'] != 'no']

print(df3.shape)
# Out:
# (344243, 30)

# %% [markdown]
# Szövegtisztítás, stemming, tokenize, stop word, számok, hashtagek, url-ek

# %%
def remove_content(text):
    text = re.sub(r"http\S+", "", text) #remove urls
    text=re.sub(r'\S+\.com\S+','',text) #remove urls
    text=re.sub(r'\@\w+','',text) #remove mentions
    text =re.sub(r'\#\w+','',text) #remove hashtags
    return text
def process_text(text, stem=False): #clean text
    text=remove_content(text)
    text = re.sub('[^A-Za-z]', ' ', text.lower()) #remove non-alphabets
    tokenized_text = word_tokenize(text) #tokenize
    clean_text = [
         word for word in tokenized_text
         if word not in stop_words
    ]
    if stem:
        clean_text=[stemmer.stem(word) for word in clean_text]
    return ' '.join(clean_text)

# %% [markdown]
# Saját stop word-ok

# %%
newStopWords = ['rt','via', 'dr', 'ex', 'trump', 'please', 'retweet', 'think', 'white', 'house', 'vote', 'goal']

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(newStopWords)
stop_words=stopwords

df3['cleaned_tweets']=df3['tweetText'].apply(lambda x: process_text(x))
# Out:
# C:\Users\laszl\Miniconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df3['cleaned_tweets'].head()
# Out:
# 0      knelt st time done done dad uncles fought clear
# 1               know howard county kokomo indiana used
# 2    one wants slapped hard wined like forever stil...
# 3    mitt romney caught taking big money donations ...
# 4                 one best anti ads ever spread around
# Name: cleaned_tweets, dtype: object

# %% [markdown]
# Szófelhő ábrázolása

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
temp=' '.join(df3['cleaned_tweets'].tolist())
wordcloud = WordCloud(width = 800, height = 500, 
                background_color ='white', 
                min_font_size = 10, max_font_size = 40, max_words=300, random_state=42,
                      colormap="gist_gray").generate(temp)
plt.figure(figsize = (20, 10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.show()
wordcloud.to_file("trump.png")

# %% [markdown]
# Republikánus szófelhő

# %%
import stylecloud

# %%
stylecloud.gen_stylecloud(temp, 
                          icon_name= "fas fa-republican", 
                          palette="cartocolors.diverging.TealRose_7", 
                          size = 1028, 
                          output_name="trump.png",
                             max_words=400,
                         random_state=10,
                         max_font_size=60)

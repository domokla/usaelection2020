# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import pandas as pd
import json
import csv
import sys
import time

ckey = 'bXRPnBdpsgRdrkfbrHBHFInjl'
csecret = 'xm93rCpGvtV6E2lwx6392l5uUfYpz9dgCe7zREGtCWeWd5b6WB'
atoken = '1191115298788777987-qUAhRZ5dAw2wN1QewZxjROvtnVLHBs'
asecret = '595HhAG8XXlbN7BPYfLVUio1ozLqmLMnFDDIaHfzPmeSv'

def toDataFrame(tweets):

    DataSet = pd.DataFrame()

    DataSet['tweetID'] = [tweet.id for tweet in tweets]
    DataSet['tweetText'] = [tweet.text for tweet in tweets]
    DataSet['tweetRetweetCt'] = [tweet.retweet_count for tweet in tweets]
    DataSet['tweetFavoriteCt'] = [tweet.favorite_count for tweet in tweets]
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['tweetCreated'] = [tweet.created_at for tweet in tweets]
    DataSet['userID'] = [tweet.user.id for tweet in tweets]
    DataSet['userScreen'] = [tweet.user.screen_name for tweet in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userCreateDt'] = [tweet.user.created_at for tweet in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
    DataSet['userFollowerCt'] = [tweet.user.followers_count for tweet in tweets]
    DataSet['userFriendsCt'] = [tweet.user.friends_count for tweet in tweets]
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
    DataSet['userTimezone'] = [tweet.user.time_zone for tweet in tweets]
    DataSet['Coordinates'] = [tweet.coordinates for tweet in tweets]
    DataSet['GeoEnabled'] = [tweet.user.geo_enabled for tweet in tweets]
    DataSet['Language'] = [tweet.user.lang for tweet in tweets]
    tweets_place= []
    #users_retweeted = []
    for tweet in tweets:
        if tweet.place:
            tweets_place.append(tweet.place.full_name)
        else:
            tweets_place.append('null')
    DataSet['TweetPlace'] = [i for i in tweets_place]
    #DataSet['UserWhoRetweeted'] = [i for i in users_retweeted]

    return DataSet

OAUTH_KEYS = {'consumer_key':ckey, 'consumer_secret':csecret,'access_token_key':atoken, 'access_token_secret':asecret}
auth = tweepy.OAuthHandler(OAUTH_KEYS['consumer_key'], OAUTH_KEYS['consumer_secret'])
#auth = tweepy.AppAuthHandler('key', 'key')

api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
if (not api):
    print ("Can't Authenticate")
    sys.exit(-1)
else:
# I am trying to download from Dec 1st to Dec 7th but I am not able to

    cursor = tweepy.Cursor(api.search, q='#creepyjoebiden',lang='en')
    results=[]
    for item in cursor.items(10000):
        results.append(item)

    DataSet = toDataFrame(results)

# %%
DataSet["text"] = DataSet["tweetText"]
DataSet.shape
# Out:
# (3562, 20)

# %%
import re
import preprocessor as p

DataSet["text"] = DataSet["tweetText"]

pd.options.display.max_colwidth = 500

def preprocess_tweet(row):
    text = row['text']
    text = p.clean(text)
    return text

DataSet["text"]  = DataSet.apply(preprocess_tweet, axis=1)

DataSet["text"] = DataSet["text"].str.lower().str.replace('[^\w\s]',' ').str.replace('\s\s+', ' ')


DataSet[["tweetText", "text"]].head()
# Out:
#                                                                                        tweetText  \
# 0  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 1  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 2  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 3  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 4  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
#
#                          text
# 0   and that s a big adios to
# 1   and that s a big adios to
# 2   and that s a big adios to
# 3   and that s a big adios to
# 4   and that s a big adios to

# %%
from nltk.tokenize import word_tokenize



def custom_tokenize(text):
    if not text:
        print('The text to be tokenized is a None type. Defaulting to blank string.')
        text = ''
    return word_tokenize(text)
DataSet['text2'] = DataSet['text'].apply(custom_tokenize)


DataSet[["text", "text2"]].head()
# Out:
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
#                          text                              text2
# 0   and that s a big adios to  [and, that, s, a, big, adios, to]
# 1   and that s a big adios to  [and, that, s, a, big, adios, to]
# 2   and that s a big adios to  [and, that, s, a, big, adios, to]
# 3   and that s a big adios to  [and, that, s, a, big, adios, to]
# 4   and that s a big adios to  [and, that, s, a, big, adios, to]

# %%
from nltk.stem.snowball import SnowballStemmer

# Use English stemmer.
stemmer = SnowballStemmer("english")

DataSet['text3'] = DataSet['text2'].apply(lambda x: [stemmer.stem(y) for y in x]) 


DataSet[["tweetText", "text2", "text3"]].head()
# Out:
#                                                                                        tweetText  \
# 0  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 1  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 2  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 3  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 4  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
#
#                                text2                             text3
# 0  [and, that, s, a, big, adios, to]  [and, that, s, a, big, adio, to]
# 1  [and, that, s, a, big, adios, to]  [and, that, s, a, big, adio, to]
# 2  [and, that, s, a, big, adios, to]  [and, that, s, a, big, adio, to]
# 3  [and, that, s, a, big, adios, to]  [and, that, s, a, big, adio, to]
# 4  [and, that, s, a, big, adios, to]  [and, that, s, a, big, adio, to]

# %%
import datetime
year = datetime.date.today().year
month = datetime.date.today().month
month = '{:02d}'.format(month)
day = datetime.date.today().day
day = '{:02d}'.format(day)

today = datetime.date.today().strftime("%Y.%m.%d")
DataSet["keresoszo"] = "#creepyjoebiden"
DataSet["letoltes_datum"] = today

# %%
DataSet.to_csv('data/creepyjoebiden' + str(year) + str(month) + str(day) + '.csv',index=False)

# %%
DataSet.head()
# Out:
#                tweetID  \
# 0  1312406699442089984
# 1  1312406608283131904
# 2  1312406556303134720
# 3  1312405736161529857
# 4  1312405323748200448
#
#                                                                                        tweetText  \
# 0  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 1  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 2  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 3  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
# 4  RT @land_terri: ......AND THAT'S A BIG\n"ADIOS" TO #CREEPYJOEBIDEN 🤪🤪 https://t.co/8t3FJRXEnD
#
#    tweetRetweetCt  tweetFavoriteCt          tweetSource        tweetCreated  \
# 0              11                0  Twitter for Android 2020-10-03 14:58:35
# 1              11                0   Twitter for iPhone 2020-10-03 14:58:13
# 2              11                0     Twitter for iPad 2020-10-03 14:58:01
# 3              11                0  Twitter for Android 2020-10-03 14:54:45
# 4              11                0   Twitter for iPhone 2020-10-03 14:53:07
#
#                 userID      userScreen                       userName  \
# 0           3057959389        NFrechen         Nicholas Frechen 🇺🇸⚖🕵️
# 1            470468291         PVTrump             P  V ❤️🇺🇸TRUMP❤️🇺🇸
# 2           3398547369        Tikal217                      Tikal.!.?
# 3   954380240687632389   DianaQuillen1                  Diana Quillen
# 4  1117290026142978048  Red_Pilled_Day  Red_Pilled_Conservative🇺🇸🇺🇸🇺🇸
#
#          userCreateDt  ... userTimezone  Coordinates  GeoEnabled Language  \
# 0 2015-03-02 19:37:42  ...         None         None       False     None
# 1 2012-01-21 20:02:12  ...         None         None        True     None
# 2 2015-08-01 11:14:35  ...         None         None       False     None
# 3 2018-01-19 15:49:15  ...         None         None       False     None
# 4 2019-04-14 04:54:35  ...         None         None       False     None
#
#   TweetPlace                        text                              text2  \
# 0       null   and that s a big adios to  [and, that, s, a, big, adios, to]
# 1       null   and that s a big adios to  [and, that, s, a, big, adios, to]
# 2       null   and that s a big adios to  [and, that, s, a, big, adios, to]
# 3       null   and that s a big adios to  [and, that, s, a, big, adios, to]
# 4       null   and that s a big adios to  [and, that, s, a, big, adios, to]
#
#                               text3        keresoszo letoltes_datum
# 0  [and, that, s, a, big, adio, to]  #creepyjoebiden     2020.10.03
# 1  [and, that, s, a, big, adio, to]  #creepyjoebiden     2020.10.03
# 2  [and, that, s, a, big, adio, to]  #creepyjoebiden     2020.10.03
# 3  [and, that, s, a, big, adio, to]  #creepyjoebiden     2020.10.03
# 4  [and, that, s, a, big, adio, to]  #creepyjoebiden     2020.10.03
#
# [5 rows x 24 columns]

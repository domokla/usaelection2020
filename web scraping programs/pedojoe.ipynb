# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import pandas as pd
import json
import csv
import sys
import time

ckey = 'bXRPnBdpsgRdrkfbrHBHFInjl'
csecret = 'xm93rCpGvtV6E2lwx6392l5uUfYpz9dgCe7zREGtCWeWd5b6WB'
atoken = '1191115298788777987-qUAhRZ5dAw2wN1QewZxjROvtnVLHBs'
asecret = '595HhAG8XXlbN7BPYfLVUio1ozLqmLMnFDDIaHfzPmeSv'

def toDataFrame(tweets):

    DataSet = pd.DataFrame()

    DataSet['tweetID'] = [tweet.id for tweet in tweets]
    DataSet['tweetText'] = [tweet.text for tweet in tweets]
    DataSet['tweetRetweetCt'] = [tweet.retweet_count for tweet in tweets]
    DataSet['tweetFavoriteCt'] = [tweet.favorite_count for tweet in tweets]
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['tweetCreated'] = [tweet.created_at for tweet in tweets]
    DataSet['userID'] = [tweet.user.id for tweet in tweets]
    DataSet['userScreen'] = [tweet.user.screen_name for tweet in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userCreateDt'] = [tweet.user.created_at for tweet in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
    DataSet['userFollowerCt'] = [tweet.user.followers_count for tweet in tweets]
    DataSet['userFriendsCt'] = [tweet.user.friends_count for tweet in tweets]
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
    DataSet['userTimezone'] = [tweet.user.time_zone for tweet in tweets]
    DataSet['Coordinates'] = [tweet.coordinates for tweet in tweets]
    DataSet['GeoEnabled'] = [tweet.user.geo_enabled for tweet in tweets]
    DataSet['Language'] = [tweet.user.lang for tweet in tweets]
    tweets_place= []
    #users_retweeted = []
    for tweet in tweets:
        if tweet.place:
            tweets_place.append(tweet.place.full_name)
        else:
            tweets_place.append('null')
    DataSet['TweetPlace'] = [i for i in tweets_place]
    #DataSet['UserWhoRetweeted'] = [i for i in users_retweeted]

    return DataSet

OAUTH_KEYS = {'consumer_key':ckey, 'consumer_secret':csecret,'access_token_key':atoken, 'access_token_secret':asecret}
auth = tweepy.OAuthHandler(OAUTH_KEYS['consumer_key'], OAUTH_KEYS['consumer_secret'])
#auth = tweepy.AppAuthHandler('key', 'key')

api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
if (not api):
    print ("Can't Authenticate")
    sys.exit(-1)
else:
# I am trying to download from Dec 1st to Dec 7th but I am not able to

    cursor = tweepy.Cursor(api.search, q='#pedojoe',lang='en')
    results=[]
    for item in cursor.items(10000):
        results.append(item)

    DataSet = toDataFrame(results)

# %%
DataSet["text"] = DataSet["tweetText"]
DataSet.shape
# Out:
# (8, 20)

# %%
import re
import preprocessor as p

DataSet["text"] = DataSet["tweetText"]

pd.options.display.max_colwidth = 500

def preprocess_tweet(row):
    text = row['text']
    text = p.clean(text)
    return text

DataSet["text"]  = DataSet.apply(preprocess_tweet, axis=1)

DataSet["text"] = DataSet["text"].str.lower().str.replace('[^\w\s]',' ').str.replace('\s\s+', ' ')


DataSet[["tweetText", "text"]].head()
# Out:
#                                                                                                                                       tweetText  \
# 0  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 1  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 2  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 3  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 4  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
#
#                                                                                                                     text
# 0   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 1   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 2   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 3   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 4   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi

# %%
from nltk.tokenize import word_tokenize



def custom_tokenize(text):
    if not text:
        print('The text to be tokenized is a None type. Defaulting to blank string.')
        text = ''
    return word_tokenize(text)
DataSet['text2'] = DataSet['text'].apply(custom_tokenize)


DataSet[["text", "text2"]].head()
# Out:
#                                                                                                                     text  \
# 0   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 1   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 2   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 3   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 4   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
#
#                                                                                                                                        text2
# 0  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 1  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 2  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 3  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 4  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]

# %%
from nltk.stem.snowball import SnowballStemmer

# Use English stemmer.
stemmer = SnowballStemmer("english")

DataSet['text3'] = DataSet['text2'].apply(lambda x: [stemmer.stem(y) for y in x]) 


DataSet[["tweetText", "text2", "text3"]].head()
# Out:
#                                                                                                                                       tweetText  \
# 0  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 1  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 2  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 3  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 4  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
#
#                                                                                                                                        text2  \
# 0  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 1  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 2  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 3  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 4  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
#
#                                                                                                                                     text3
# 0  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]
# 1  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]
# 2  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]
# 3  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]
# 4  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]

# %%
import datetime
year = datetime.date.today().year
month = datetime.date.today().month
month = '{:02d}'.format(month)
day = datetime.date.today().day
day = '{:02d}'.format(day)

today = datetime.date.today().strftime("%Y.%m.%d")
DataSet["keresoszo"] = "#pedojoe"
DataSet["letoltes_datum"] = today

# %%
DataSet.to_csv('data/pedojoe' + str(year) + str(month) + str(day) + '.csv',index=False)

# %%
DataSet.head()
# Out:
#                tweetID  \
# 0  1312377746971127809
# 1  1312324070088867840
# 2  1312313054554722305
# 3  1312312478051692546
# 4  1312257095933333505
#
#                                                                                                                                       tweetText  \
# 0  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 1  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 2  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 3  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
# 4  RT @JesseKellyDC: Why hasn’t Joe Biden denounced pedophilia yet? This shouldn’t be hard. Does Joe Biden support pedophilia? Is he a pedophi…
#
#    tweetRetweetCt  tweetFavoriteCt         tweetSource        tweetCreated  \
# 0             762                0  Twitter for iPhone 2020-10-03 13:03:32
# 1             762                0     Twitter Web App 2020-10-03 09:30:14
# 2             762                0    Twitter for iPad 2020-10-03 08:46:28
# 3             762                0  Twitter for iPhone 2020-10-03 08:44:11
# 4             762                0    Twitter for iPad 2020-10-03 05:04:06
#
#                 userID       userScreen              userName  \
# 0            241922327   DanStevens1103           Dan Stevens
# 1   786948639197372416  ProbableCause45  ❌Wayne-Upstate,S.C.❌
# 2           2468328434       HambrickRo        Robin Hambrick
# 3  1244745463074455552        Spankin40               Spankin
# 4            865636782     Maxinerunner                Maxine
#
#          userCreateDt  ... userTimezone  Coordinates  GeoEnabled Language  \
# 0 2011-01-23 13:43:57  ...         None         None       False     None
# 1 2016-10-14 15:15:51  ...         None         None       False     None
# 2 2014-04-28 22:12:44  ...         None         None       False     None
# 3 2020-03-30 21:57:10  ...         None         None       False     None
# 4 2012-10-07 02:30:46  ...         None         None       False     None
#
#   TweetPlace  \
# 0       null
# 1       null
# 2       null
# 3       null
# 4       null
#
#                                                                                                                     text  \
# 0   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 1   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 2   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 3   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
# 4   why hasnt joe biden denounced pedophilia yet this shouldnt be hard does joe biden support pedophilia is he a pedophi
#
#                                                                                                                                        text2  \
# 0  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 1  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 2  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 3  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
# 4  [why, hasnt, joe, biden, denounced, pedophilia, yet, this, shouldnt, be, hard, does, joe, biden, support, pedophilia, is, he, a, pedophi]
#
#                                                                                                                                     text3  \
# 0  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]
# 1  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]
# 2  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]
# 3  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]
# 4  [whi, hasnt, joe, biden, denounc, pedophilia, yet, this, shouldnt, be, hard, doe, joe, biden, support, pedophilia, is, he, a, pedophi]
#
#   keresoszo letoltes_datum
# 0  #pedojoe     2020.10.03
# 1  #pedojoe     2020.10.03
# 2  #pedojoe     2020.10.03
# 3  #pedojoe     2020.10.03
# 4  #pedojoe     2020.10.03
#
# [5 rows x 24 columns]

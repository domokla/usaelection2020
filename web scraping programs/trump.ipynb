# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import pandas as pd
import json
import csv
import sys
import time

ckey = 'bXRPnBdpsgRdrkfbrHBHFInjl'
csecret = 'xm93rCpGvtV6E2lwx6392l5uUfYpz9dgCe7zREGtCWeWd5b6WB'
atoken = '1191115298788777987-qUAhRZ5dAw2wN1QewZxjROvtnVLHBs'
asecret = '595HhAG8XXlbN7BPYfLVUio1ozLqmLMnFDDIaHfzPmeSv'

def toDataFrame(tweets):

    DataSet = pd.DataFrame()

    DataSet['tweetID'] = [tweet.id for tweet in tweets]
    DataSet['tweetText'] = [tweet.text for tweet in tweets]
    DataSet['tweetRetweetCt'] = [tweet.retweet_count for tweet in tweets]
    DataSet['tweetFavoriteCt'] = [tweet.favorite_count for tweet in tweets]
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['tweetCreated'] = [tweet.created_at for tweet in tweets]
    DataSet['userID'] = [tweet.user.id for tweet in tweets]
    DataSet['userScreen'] = [tweet.user.screen_name for tweet in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userCreateDt'] = [tweet.user.created_at for tweet in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
    DataSet['userFollowerCt'] = [tweet.user.followers_count for tweet in tweets]
    DataSet['userFriendsCt'] = [tweet.user.friends_count for tweet in tweets]
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
    DataSet['userTimezone'] = [tweet.user.time_zone for tweet in tweets]
    DataSet['Coordinates'] = [tweet.coordinates for tweet in tweets]
    DataSet['GeoEnabled'] = [tweet.user.geo_enabled for tweet in tweets]
    DataSet['Language'] = [tweet.user.lang for tweet in tweets]
    tweets_place= []
    #users_retweeted = []
    for tweet in tweets:
        if tweet.place:
            tweets_place.append(tweet.place.full_name)
        else:
            tweets_place.append('null')
    DataSet['TweetPlace'] = [i for i in tweets_place]
    #DataSet['UserWhoRetweeted'] = [i for i in users_retweeted]

    return DataSet

OAUTH_KEYS = {'consumer_key':ckey, 'consumer_secret':csecret,'access_token_key':atoken, 'access_token_secret':asecret}
auth = tweepy.OAuthHandler(OAUTH_KEYS['consumer_key'], OAUTH_KEYS['consumer_secret'])
#auth = tweepy.AppAuthHandler('key', 'key')

api = tweepy.API(auth, wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
if (not api):
    print ("Can't Authenticate")
    sys.exit(-1)
else:
# I am trying to download from Dec 1st to Dec 7th but I am not able to

    cursor = tweepy.Cursor(api.search, q='#trump',lang='en')
    results=[]
    for item in cursor.items(10000):
        results.append(item)

    DataSet = toDataFrame(results)
# Out:
# Rate limit reached. Sleeping for: 162
# Rate limit reached. Sleeping for: 696

# %%
DataSet["text"] = DataSet["tweetText"]
DataSet.shape
# Out:
# (10000, 20)

# %%
import re
import preprocessor as p

DataSet["text"] = DataSet["tweetText"]

pd.options.display.max_colwidth = 500

def preprocess_tweet(row):
    text = row['text']
    text = p.clean(text)
    return text

DataSet["text"]  = DataSet.apply(preprocess_tweet, axis=1)

DataSet["text"] = DataSet["text"].str.lower().str.replace('[^\w\s]',' ').str.replace('\s\s+', ' ')


DataSet[["tweetText", "text"]].head()
# Out:
#                                                                                                                                       tweetText  \
# 0   RT @amjoyshow: .@Yamiche: Just a few days ago #Trump said the end of the #pandemic is near. Now we see something unfolding in the U.S. you…
# 1         #WorthReading\n\n#MichaelMoore @MMFlint floats conspiracy theory that #Trump may be #Faking COVID Diagnosis.\nhttps://t.co/v4Sp5AS9ff
# 2  RT @monaeltahawy: I have zero sympathy for #Trump and refuse to be civil or polite about it. To socialize us into obedience and maintain it…
# 3  RT @DumoHayise: Please spread the word 1😭😭😭😭 #humantraffickingawareness #Get2GetherExperience #HitRefresh #Trump #COVID19 https://t.co/1l9c…
# 4  RT @DumoHayise: Please spread the word 1😭😭😭😭 #humantraffickingawareness #Get2GetherExperience #HitRefresh #Trump #COVID19 https://t.co/1l9c…
#
#                                                                                                                  text
# 0                       just a few days ago said the end of the is near now we see something unfolding in the u s you
# 1                                                               floats conspiracy theory that may be covid diagnosis
# 2   i have zero sympathy for and refuse to be civil or polite about it to socialize us into obedience and maintain it
# 3                                                                                              please spread the word
# 4                                                                                              please spread the word

# %%
from nltk.tokenize import word_tokenize



def custom_tokenize(text):
    if not text:
        print('The text to be tokenized is a None type. Defaulting to blank string.')
        text = ''
    return word_tokenize(text)
DataSet['text2'] = DataSet['text'].apply(custom_tokenize)


DataSet[["text", "text2"]].head()
# Out:
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
# The text to be tokenized is a None type. Defaulting to blank string.
#                                                                                                                  text  \
# 0                       just a few days ago said the end of the is near now we see something unfolding in the u s you
# 1                                                               floats conspiracy theory that may be covid diagnosis
# 2   i have zero sympathy for and refuse to be civil or polite about it to socialize us into obedience and maintain it
# 3                                                                                              please spread the word
# 4                                                                                              please spread the word
#
#                                                                                                                                       text2
# 0                      [just, a, few, days, ago, said, the, end, of, the, is, near, now, we, see, something, unfolding, in, the, u, s, you]
# 1                                                                             [floats, conspiracy, theory, that, may, be, covid, diagnosis]
# 2  [i, have, zero, sympathy, for, and, refuse, to, be, civil, or, polite, about, it, to, socialize, us, into, obedience, and, maintain, it]
# 3                                                                                                               [please, spread, the, word]
# 4                                                                                                               [please, spread, the, word]

# %%
from nltk.stem.snowball import SnowballStemmer

# Use English stemmer.
stemmer = SnowballStemmer("english")

DataSet['text3'] = DataSet['text2'].apply(lambda x: [stemmer.stem(y) for y in x]) 


DataSet[["tweetText", "text2", "text3"]].head()
# Out:
#                                                                                                                                       tweetText  \
# 0   RT @amjoyshow: .@Yamiche: Just a few days ago #Trump said the end of the #pandemic is near. Now we see something unfolding in the U.S. you…
# 1         #WorthReading\n\n#MichaelMoore @MMFlint floats conspiracy theory that #Trump may be #Faking COVID Diagnosis.\nhttps://t.co/v4Sp5AS9ff
# 2  RT @monaeltahawy: I have zero sympathy for #Trump and refuse to be civil or polite about it. To socialize us into obedience and maintain it…
# 3  RT @DumoHayise: Please spread the word 1😭😭😭😭 #humantraffickingawareness #Get2GetherExperience #HitRefresh #Trump #COVID19 https://t.co/1l9c…
# 4  RT @DumoHayise: Please spread the word 1😭😭😭😭 #humantraffickingawareness #Get2GetherExperience #HitRefresh #Trump #COVID19 https://t.co/1l9c…
#
#                                                                                                                                       text2  \
# 0                      [just, a, few, days, ago, said, the, end, of, the, is, near, now, we, see, something, unfolding, in, the, u, s, you]
# 1                                                                             [floats, conspiracy, theory, that, may, be, covid, diagnosis]
# 2  [i, have, zero, sympathy, for, and, refuse, to, be, civil, or, polite, about, it, to, socialize, us, into, obedience, and, maintain, it]
# 3                                                                                                               [please, spread, the, word]
# 4                                                                                                               [please, spread, the, word]
#
#                                                                                                                              text3
# 0                    [just, a, few, day, ago, said, the, end, of, the, is, near, now, we, see, someth, unfold, in, the, u, s, you]
# 1                                                                      [float, conspiraci, theori, that, may, be, covid, diagnosi]
# 2  [i, have, zero, sympathi, for, and, refus, to, be, civil, or, polit, about, it, to, social, us, into, obedi, and, maintain, it]
# 3                                                                                                       [pleas, spread, the, word]
# 4                                                                                                       [pleas, spread, the, word]

# %%
import datetime
year = datetime.date.today().year
month = datetime.date.today().month
month = '{:02d}'.format(month)
day = datetime.date.today().day
day = '{:02d}'.format(day)

today = datetime.date.today().strftime("%Y.%m.%d")
DataSet["keresoszo"] = "#trump"
DataSet["letoltes_datum"] = today

# %%
DataSet.to_csv('data/trump' + str(year) + str(month) + str(day) + '.csv',index=False)

# %%
DataSet.head()
# Out:
#                tweetID  \
# 0  1312398836757868544
# 1  1312398834996113409
# 2  1312398834539155463
# 3  1312398833842880513
# 4  1312398833641566208
#
#                                                                                                                                       tweetText  \
# 0   RT @amjoyshow: .@Yamiche: Just a few days ago #Trump said the end of the #pandemic is near. Now we see something unfolding in the U.S. you…
# 1         #WorthReading\n\n#MichaelMoore @MMFlint floats conspiracy theory that #Trump may be #Faking COVID Diagnosis.\nhttps://t.co/v4Sp5AS9ff
# 2  RT @monaeltahawy: I have zero sympathy for #Trump and refuse to be civil or polite about it. To socialize us into obedience and maintain it…
# 3  RT @DumoHayise: Please spread the word 1😭😭😭😭 #humantraffickingawareness #Get2GetherExperience #HitRefresh #Trump #COVID19 https://t.co/1l9c…
# 4  RT @DumoHayise: Please spread the word 1😭😭😭😭 #humantraffickingawareness #Get2GetherExperience #HitRefresh #Trump #COVID19 https://t.co/1l9c…
#
#    tweetRetweetCt  tweetFavoriteCt          tweetSource        tweetCreated  \
# 0              97                0     Twitter for iPad 2020-10-03 14:27:20
# 1               0                0      Twitter Web App 2020-10-03 14:27:20
# 2             247                0  Twitter for Android 2020-10-03 14:27:20
# 3            6958                0  Twitter for Android 2020-10-03 14:27:19
# 4            6958                0  Twitter for Android 2020-10-03 14:27:19
#
#                 userID       userScreen              userName  \
# 0  1244439392527187973  Barbara64444460         Barbara Wells
# 1            151495144      mexobserver           Sol x #DDHH
# 2             63028590     ChicagoWhite  Leeds Fan in Chicago
# 3   998596951372419072        ThatileOn            On.Thatile
# 4  1229509148821331968     travis_uncle        Travis Hlalele
#
#          userCreateDt  ... userTimezone  Coordinates  GeoEnabled Language  \
# 0 2020-03-30 01:41:27  ...         None         None       False     None
# 1 2010-06-03 14:48:17  ...         None         None        True     None
# 2 2009-08-05 04:12:33  ...         None         None        True     None
# 3 2018-05-21 16:10:41  ...         None         None       False     None
# 4 2020-02-17 20:53:31  ...         None         None       False     None
#
#   TweetPlace  \
# 0       null
# 1       null
# 2       null
# 3       null
# 4       null
#
#                                                                                                                  text  \
# 0                       just a few days ago said the end of the is near now we see something unfolding in the u s you
# 1                                                               floats conspiracy theory that may be covid diagnosis
# 2   i have zero sympathy for and refuse to be civil or polite about it to socialize us into obedience and maintain it
# 3                                                                                              please spread the word
# 4                                                                                              please spread the word
#
#                                                                                                                                       text2  \
# 0                      [just, a, few, days, ago, said, the, end, of, the, is, near, now, we, see, something, unfolding, in, the, u, s, you]
# 1                                                                             [floats, conspiracy, theory, that, may, be, covid, diagnosis]
# 2  [i, have, zero, sympathy, for, and, refuse, to, be, civil, or, polite, about, it, to, socialize, us, into, obedience, and, maintain, it]
# 3                                                                                                               [please, spread, the, word]
# 4                                                                                                               [please, spread, the, word]
#
#                                                                                                                              text3  \
# 0                    [just, a, few, day, ago, said, the, end, of, the, is, near, now, we, see, someth, unfold, in, the, u, s, you]
# 1                                                                      [float, conspiraci, theori, that, may, be, covid, diagnosi]
# 2  [i, have, zero, sympathi, for, and, refus, to, be, civil, or, polit, about, it, to, social, us, into, obedi, and, maintain, it]
# 3                                                                                                       [pleas, spread, the, word]
# 4                                                                                                       [pleas, spread, the, word]
#
#   keresoszo letoltes_datum
# 0    #trump     2020.10.03
# 1    #trump     2020.10.03
# 2    #trump     2020.10.03
# 3    #trump     2020.10.03
# 4    #trump     2020.10.03
#
# [5 rows x 24 columns]
